# %%
import pandas as pd
from matplotlib import pyplot as plt
train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
df=pd.read_csv("beauty.csv")

# %%
df
# Out:
#        wage  exper  union  goodhlth  black  female  married  service  educ  \
# 0      5.73     30      0         1      0       1        1        1    14
# 1      4.28     28      0         1      0       1        1        0    12
# 2      7.96     35      0         1      0       1        0        0    10
# 3     11.57     38      0         1      0       0        1        1    16
# 4     11.42     27      0         1      0       0        1        0    16
# 5      3.91     20      0         0      0       1        1        0    12
# 6      8.76     12      0         1      0       0        1        0    16
# 7      7.69      5      1         1      0       0        0        0    16
# 8      5.00      5      0         1      0       1        0        0    16
# 9      3.89     12      0         1      0       1        0        0    12
# 10     3.45      3      0         1      0       1        0        0    12
# ...

# %%
df.head()
# Out:
#     wage  exper  union  goodhlth  black  female  married  service  educ  looks
# 0   5.73     30      0         1      0       1        1        1    14      4
# 1   4.28     28      0         1      0       1        1        0    12      3
# 2   7.96     35      0         1      0       1        0        0    10      4
# 3  11.57     38      0         1      0       0        1        1    16      3
# 4  11.42     27      0         1      0       0        1        0    16      3

# %%
df['wage'].head()
# Out:
# 0     5.73
# 1     4.28
# 2     7.96
# 3    11.57
# 4    11.42
# Name: wage, dtype: float64

# %%
df.shape
# Out:
# (1260, 10)

# %% [markdown]
# df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 10 columns):
# wage        1260 non-null float64
# exper       1260 non-null int64
# union       1260 non-null int64
# goodhlth    1260 non-null int64
# black       1260 non-null int64
# female      1260 non-null int64
# married     1260 non-null int64
# service     1260 non-null int64
# educ        1260 non-null int64
# looks       1260 non-null int64
# dtypes: float64(1), int64(9)
# memory usage: 98.5 KB

# %%
df.describe()
# Out:
#               wage        exper        union     goodhlth        black  \
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      6.306690    18.206349     0.272222     0.933333     0.073810
# std       4.660639    11.963485     0.445280     0.249543     0.261564
# min       1.020000     0.000000     0.000000     0.000000     0.000000
# 25%       3.707500     8.000000     0.000000     1.000000     0.000000
# 50%       5.300000    15.000000     0.000000     1.000000     0.000000
# 75%       7.695000    27.000000     1.000000     1.000000     0.000000
# max      77.720000    48.000000     1.000000     1.000000     1.000000
#
#             female      married      service         educ        looks
# count  1260.000000  1260.000000  1260.000000  1260.000000  1260.000000
# mean      0.346032     0.691270     0.273810    12.563492     3.185714
# std       0.475892     0.462153     0.446089     2.624489     0.684877
# ...

# %%
df['wage'].hist();

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CF0D558C18>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(12,8))
df.hist();

# %%
df['female'].value_counts()
# Out:
# 0    824
# 1    436
# Name: female, dtype: int64

# %%
df['goodhlth'].value_counts(normalize=True)
# Out:
# 1    0.933333
# 0    0.066667
# Name: goodhlth, dtype: float64

# %%
#INDEXING

# %%
##INdex

# %%
#### .iloc (~NumPy array)

# %%
#### .iloc (~NumPy array)

# %%
df.iloc[0,5]
# Out:
# 1

# %%
df.iloc[:6,5:7]
# Out:
#    female  married
# 0       1        1
# 1       1        1
# 2       1        0
# 3       0        1
# 4       0        1
# 5       1        1

# %% [markdown]
# # .loc

# %% [markdown]
# # boolean indexing

# %%
df['wage'] > 40
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1230    False
# 1231    False
# 1232    False
# 1233    False
# 1234    False
# 1235    False
# 1236    False
# 1237    False
# 1238    False
# 1239    False
# 1240    False
# 1241    False
# 1242    False
# 1243    False
# 1244    False
# 1245    False
# 1246    False
# 1247    False
# 1248    False
# 1249    False
# 1250    False
# 1251    False
# 1252    False
# 1253    False
# 1254    False
# 1255    False
# 1256    False
# 1257    False
# 1258    False
# 1259    False
# ...

# %%
df[df['wage'] > 40]
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 269  41.67     16      0         0      0       0        1        0    13
# 602  77.72      9      1         1      1       1        1        1    13
#
#      looks
# 269      4
# 602      4

# %%
df[(df['wage'] > 40) & (df['female']==1)]
# Out:
#       wage  exper  union  goodhlth  black  female  married  service  educ  \
# 602  77.72      9      1         1      1       1        1        1    13
#
#      looks
# 602      4

# %% [markdown]
# ## apply

# %%
def gendr_id(id):
    return 'female' if id==1 else 'male'

# %%
df['female'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# Name: female, dtype: int64

# %%
df['female'].apply(gendr_id)
# Out:
# 0       female
# 1       female
# 2       female
# 3         male
# 4         male
# 5       female
# 6         male
# 7         male
# 8       female
# 9       female
# 10      female
# 11        male
# 12        male
# 13        male
# 14        male
# 15        male
# 16        male
# 17        male
# 18      female
# 19      female
# 20        male
# 21        male
# 22        male
# 23        male
# 24        male
# 25        male
# 26        male
# 27        male
# 28        male
# 29        male
#          ...
# 1230      male
# 1231      male
# 1232      male
# 1233      male
# 1234    female
# 1235      male
# 1236      male
# 1237      male
# 1238      male
# 1239      male
# 1240      male
# 1241      male
# 1242      male
# 1243      male
# 1244      male
# 1245      male
# 1246      male
# 1247      male
# 1248      male
# 1249      male
# 1250      male
# 1251      male
# 1252      male
# 1253    female
# 1254    female
# 1255    female
# 1256    female
# ...

# %% [markdown]
# ### writing function inside data

# %% [markdown]
# ## lambda

# %%
df['female'].apply(lambda id: 
                   'female' if id==1 else 'male').head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: female, dtype: object

# %% [markdown]
# ### map

# %%
df['female'].map({0: 'male', 1: 'female'}).head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: female, dtype: object

# %%
import seaborn as sns

# %%
df['educ'].value_counts()
# Out:
# 12    468
# 13    246
# 10    156
# 17    132
# 16    121
# 14     51
# 8      44
# 5      42
# Name: educ, dtype: int64

# %% [markdown]
# ## PART 2 Data visuaization

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
df.shape
# Out:
# (800, 12)

# %% [markdown]
# # whole dataset visualization

# %%
df['Legendary']=df['Legendary'].map({'Yes': 1, 'No': 0})

# %%
df=pd.read_csv('https://raw.githubusercontent.com/rajprakrit/mlcourse.ai/master/data/telecom_churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.shape
# Out:
# (3333, 20)

# %%
df.drop('State')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-5cbb085de5ed> in <module>
# ----> 1 df.drop('State')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
# ...

# %%
df.drop('State', axis=1)
# Out:
#       Account length  Area code International plan Voice mail plan  \
# 0                128        415                 No             Yes
# 1                107        415                 No             Yes
# 2                137        415                 No              No
# 3                 84        408                Yes              No
# 4                 75        415                Yes              No
# 5                118        510                Yes              No
# 6                121        510                 No             Yes
# 7                147        415                Yes              No
# 8                117        408                 No              No
# 9                141        415                Yes             Yes
# 10                65        415                 No              No
# 11                74        415                 No              No
# 12               168        408                 No              No
# ...

# %%
df['International plan']=df['International plan'].map({'Yes': 1, 'No':0})
df['Voice mail plan']=df['Voice mail plan'].map({'Yes': 1, 'No':0})

# %%
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415                   0                1
# 1    OH             107        415                   0                1
# 2    NJ             137        415                   0                0
# 3    OH              84        408                   1                0
# 4    OK              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
df.drop('State', axis=1)
df.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415                   0                1
# 1    OH             107        415                   0                1
# 2    NJ             137        415                   0                0
# 3    OH              84        408                   1                0
# 4    OK              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
plt.rcParams['figure.figsize'] = (16,12)
df.drop(['State', 'Churn'], axis=1).hist();

# %%
df['Churn'] = df['Churn'].astype('int')
plt.rcParams['figure.figsize'] = (16,12)
df.drop(['State'], axis=1).hist();

# %% [markdown]
# ## axis=1 specifies that we want to delee columns

# %%
sns.heatmap(df.corr());

# %% [markdown]
# ## charge and mintues are propotional to each other so we only need one of them

# %%
df.drop([feat_name for feat_name in df.columns
 if 'charge' in feat_name], axis=1, inplace=True)

# %% [markdown]
# ## data frame got changed by adding inplace =True

# %%
df.shape
# Out:
# (3333, 16)

# %%
[feat_name for feat_name in df.columns
 if 'charge' in feat_name]
# Out:
# []

# %%
df['Total day minutes'].describe()
# Out:
# count    3333.000000
# mean      179.775098
# std        54.467389
# min         0.000000
# 25%       143.700000
# 50%       179.400000
# 75%       216.400000
# max       350.800000
# Name: Total day minutes, dtype: float64

# %%
sns.boxplot(x='Total day minutes', data = df)

# %%
df['State'].nunique()
# Out:
# 51

# %%
df['State'].value_counts().head()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# Name: State, dtype: int64

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# 0    0.855086
# 1    0.144914
# Name: Churn, dtype: float64

# %%
sns.countplot(x='Churn', data=df)
